# %%
import tensorflow as tf
from tensorflow import keras
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np

# %%
BATCH_SIZE = 32
IMAGE_LENGTH = 256
IMAGE_BREADTH = 256
CHANNELS = 3
EPOCHS = 40

# %%
dataset = tf.keras.preprocessing.image_dataset_from_directory(
    '../DataSet/Pepper_Bell',
    batch_size = BATCH_SIZE,
    shuffle = True,
    image_size = (IMAGE_LENGTH, IMAGE_BREADTH)
)
# Out:
# Found 2475 files belonging to 2 classes.

# %%
class_names = dataset.class_names
class_names
# Out:
# ['Pepper__bell___Bacterial_spot', 'Pepper__bell___healthy']

# %%
TRAIN_FRACTION = 0.8
VALIDATE_FRACTION = 0.1
TEST_FRACTION = 0.1

ds_size = len(dataset)
train_size = int(len(dataset)*TRAIN_FRACTION)
val_size = int(len(dataset)*VALIDATE_FRACTION)
test_size = int(len(dataset)*TEST_FRACTION)

train = dataset.take(train_size)
val = dataset.skip(train_size).take(val_size)
test = dataset.skip(train_size).skip(val_size)
ds_size = [len(train), len(val), len(test)]
ds_size
# Out:
# [62, 7, 9]

# %%
train = train.cache().shuffle(1000).prefetch(buffer_size = tf.data.AUTOTUNE)
val = val.cache().shuffle(1000).prefetch(buffer_size = tf.data.AUTOTUNE)
test = test.cache().shuffle(1000).prefetch(buffer_size = tf.data.AUTOTUNE)

# %%
tf.config.list_physical_devices()
# Out:
# [PhysicalDevice(name='/physical_device:CPU:0', device_type='CPU'),
#  PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
adjust = tf.keras.Sequential([
    keras.layers.Rescaling(1.0/255),
    keras.layers.Resizing(IMAGE_LENGTH, IMAGE_BREADTH)
])

augment = tf.keras.Sequential([
    keras.layers.RandomFlip('horizontal_and_vertical'),
    keras.layers.RandomRotation(0.2)
])

# %%
input_dimensions = (BATCH_SIZE, IMAGE_LENGTH, IMAGE_BREADTH, CHANNELS)


model = keras.models.Sequential([
    adjust,
    augment,
    
    keras.layers.Conv2D(32, (3, 3), input_shape = input_dimensions, activation = 'relu'),
    keras.layers.MaxPool2D(2, 2),
    
    keras.layers.Conv2D(64, (3, 3), activation = 'relu'),
    keras.layers.MaxPool2D(2, 2),
    
    keras.layers.Conv2D(64, (3, 3), activation = 'relu'),
    keras.layers.MaxPool2D(2, 2),
    
    keras.layers.Conv2D(64, (3, 3), activation = 'relu'),
    keras.layers.MaxPool2D(2, 2),
    
    keras.layers.Conv2D(64, (3, 3), activation = 'relu'),
    keras.layers.MaxPool2D(2, 2),
    
    keras.layers.Conv2D(64, (3, 3), activation = 'relu'),
    keras.layers.MaxPool2D(2, 2),

    keras.layers.Flatten(),
    keras.layers.Dense(64, activation='relu'),
    keras.layers.Dense(len(class_names), activation='softmax')

])

model.build(input_shape = input_dimensions)

# %%
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  sequential (Sequential)     (32, 256, 256, 3)         0
#
#  sequential_1 (Sequential)   (32, 256, 256, 3)         0
#
#  conv2d (Conv2D)             (32, 254, 254, 32)        896
#
#  max_pooling2d (MaxPooling2D  (32, 127, 127, 32)       0
#  )
#
#  conv2d_1 (Conv2D)           (32, 125, 125, 64)        18496
#
#  max_pooling2d_1 (MaxPooling  (32, 62, 62, 64)         0
#  2D)
#
#  conv2d_2 (Conv2D)           (32, 60, 60, 64)          36928
#
#  max_pooling2d_2 (MaxPooling  (32, 30, 30, 64)         0
#  2D)
#
#  conv2d_3 (Conv2D)           (32, 28, 28, 64)          36928
#
#  max_pooling2d_3 (MaxPooling  (32, 14, 14, 64)         0
#  2D)
#
#  conv2d_4 (Conv2D)           (32, 12, 12, 64)          36928
#
#  max_pooling2d_4 (MaxPooling  (32, 6, 6, 64)           0
#  2D)
#
#  conv2d_5 (Conv2D)           (32, 4, 4, 64)            36928
#
#  max_pooling2d_5 (MaxPooling  (32, 2, 2, 64)           0
#  2D)
#
#  flatten (Flatten)           (32, 256)                 0
#
#  dense (Dense)               (32, 64)                  16448
#
#  dense_1 (Dense)             (32, 2)                   130
#
# =================================================================
# Total params: 183,682
# Trainable params: 183,682
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(
    optimizer = 'adam',
    loss = tf.keras.losses.SparseCategoricalCrossentropy(),
    metrics = ['accuracy']
)

# %%
# with tf.device('/GPU:0'):
history = model.fit(
    train,
    epochs = EPOCHS,
    batch_size = BATCH_SIZE,
    verbose = 1,
    validation_data = val
)
# Out:
# Epoch 1/40
# 62/62 [==============================] - 40s 379ms/step - loss: 0.6283 - accuracy: 0.6850 - val_loss: 0.5211 - val_accuracy: 0.7768
# Epoch 2/40
# 62/62 [==============================] - 13s 202ms/step - loss: 0.2676 - accuracy: 0.9012 - val_loss: 0.5364 - val_accuracy: 0.9554
# Epoch 3/40
# 62/62 [==============================] - 13s 207ms/step - loss: 0.1183 - accuracy: 0.9617 - val_loss: 0.7502 - val_accuracy: 0.9643
# Epoch 4/40
# 62/62 [==============================] - 13s 208ms/step - loss: 0.0600 - accuracy: 0.9829 - val_loss: 0.4237 - val_accuracy: 0.9866
# Epoch 5/40
# 62/62 [==============================] - 13s 212ms/step - loss: 0.0787 - accuracy: 0.9798 - val_loss: 0.3230 - val_accuracy: 0.9866
# Epoch 6/40
# 62/62 [==============================] - 13s 213ms/step - loss: 0.0296 - accuracy: 0.9924 - val_loss: 0.2662 - val_accuracy: 0.9866
# Epoch 7/40
# 62/62 [==============================] - 13s 215ms/step - loss: 0.0225 - accuracy: 0.9940 - val_loss: 0.3810 - val_accuracy: 0.9821
# Epoch 8/40
# 62/62 [==============================] - 14s 221ms/step - loss: 0.0253 - accuracy: 0.9914 - val_loss: 0.2034 - val_accuracy: 0.9688
# Epoch 9/40
# 62/62 [==============================] - 14s 230ms/step - loss: 0.0254 - accuracy: 0.9929 - val_loss: 0.2193 - val_accuracy: 0.9732
# Epoch 10/40
# 62/62 [==============================] - 14s 221ms/step - loss: 0.0272 - accuracy: 0.9919 - val_loss: 0.2388 - val_accuracy: 0.9821
# Epoch 11/40
# 62/62 [==============================] - 14s 227ms/step - loss: 0.0292 - accuracy: 0.9924 - val_loss: 0.2906 - val_accuracy: 0.9732
# Epoch 12/40
# 62/62 [==============================] - 14s 226ms/step - loss: 0.0178 - accuracy: 0.9955 - val_loss: 0.2767 - val_accuracy: 0.9866
# Epoch 13/40
# 62/62 [==============================] - 14s 224ms/step - loss: 0.0665 - accuracy: 0.9808 - val_loss: 0.2852 - val_accuracy: 0.9866
# Epoch 14/40
# 62/62 [==============================] - 15s 234ms/step - loss: 0.0301 - accuracy: 0.9904 - val_loss: 0.4802 - val_accuracy: 0.9866
# Epoch 15/40
# 62/62 [==============================] - 14s 230ms/step - loss: 0.0244 - accuracy: 0.9929 - val_loss: 0.2479 - val_accuracy: 0.9866
# Epoch 16/40
# 62/62 [==============================] - 14s 230ms/step - loss: 0.0193 - accuracy: 0.9924 - val_loss: 0.3062 - val_accuracy: 0.9911
# Epoch 17/40
# 62/62 [==============================] - 15s 238ms/step - loss: 0.0204 - accuracy: 0.9950 - val_loss: 0.2231 - val_accuracy: 0.9911
# Epoch 18/40
# 62/62 [==============================] - 15s 238ms/step - loss: 0.0121 - accuracy: 0.9960 - val_loss: 0.1801 - val_accuracy: 0.9866
# Epoch 19/40
# 62/62 [==============================] - 15s 243ms/step - loss: 0.0167 - accuracy: 0.9950 - val_loss: 0.3086 - val_accuracy: 0.9777
# Epoch 20/40
# 62/62 [==============================] - 15s 241ms/step - loss: 0.0191 - accuracy: 0.9950 - val_loss: 0.3792 - val_accuracy: 0.9777
# Epoch 21/40
# 62/62 [==============================] - 15s 245ms/step - loss: 0.0166 - accuracy: 0.9950 - val_loss: 0.3337 - val_accuracy: 0.9866
# Epoch 22/40
# 62/62 [==============================] - 15s 242ms/step - loss: 0.0194 - accuracy: 0.9940 - val_loss: 0.3611 - val_accuracy: 0.9955
# Epoch 23/40
# 62/62 [==============================] - 15s 243ms/step - loss: 0.0163 - accuracy: 0.9960 - val_loss: 0.3688 - val_accuracy: 0.9821
# Epoch 24/40
# 62/62 [==============================] - 15s 242ms/step - loss: 0.0225 - accuracy: 0.9960 - val_loss: 0.2725 - val_accuracy: 0.9911
# Epoch 25/40
# 62/62 [==============================] - 15s 247ms/step - loss: 0.0164 - accuracy: 0.9965 - val_loss: 0.3602 - val_accuracy: 0.9688
# Epoch 26/40
# 62/62 [==============================] - 15s 246ms/step - loss: 0.0182 - accuracy: 0.9955 - val_loss: 0.1547 - val_accuracy: 0.9955
# Epoch 27/40
# 62/62 [==============================] - 16s 252ms/step - loss: 0.0256 - accuracy: 0.9889 - val_loss: 0.1411 - val_accuracy: 0.9866
# Epoch 28/40
# 62/62 [==============================] - 15s 247ms/step - loss: 0.0207 - accuracy: 0.9955 - val_loss: 0.1946 - val_accuracy: 0.9955
# Epoch 29/40
# 62/62 [==============================] - 16s 254ms/step - loss: 0.0175 - accuracy: 0.9955 - val_loss: 0.2854 - val_accuracy: 0.9911
# Epoch 30/40
# 62/62 [==============================] - 16s 260ms/step - loss: 0.0097 - accuracy: 0.9975 - val_loss: 0.3170 - val_accuracy: 0.9955
# Epoch 31/40
# 62/62 [==============================] - 16s 254ms/step - loss: 0.0154 - accuracy: 0.9934 - val_loss: 0.2623 - val_accuracy: 0.9911
# Epoch 32/40
# 62/62 [==============================] - 16s 254ms/step - loss: 0.0186 - accuracy: 0.9960 - val_loss: 0.2949 - val_accuracy: 0.9911
# Epoch 33/40
# 62/62 [==============================] - 16s 260ms/step - loss: 0.0097 - accuracy: 0.9960 - val_loss: 0.3652 - val_accuracy: 0.9911
# Epoch 34/40
# 62/62 [==============================] - 16s 265ms/step - loss: 0.0173 - accuracy: 0.9950 - val_loss: 0.2259 - val_accuracy: 0.9821
# Epoch 35/40
# 62/62 [==============================] - 16s 264ms/step - loss: 0.0183 - accuracy: 0.9929 - val_loss: 0.1608 - val_accuracy: 0.9955
# Epoch 36/40
# 62/62 [==============================] - 16s 260ms/step - loss: 0.0115 - accuracy: 0.9960 - val_loss: 0.1597 - val_accuracy: 0.9955
# Epoch 37/40
# 62/62 [==============================] - 17s 267ms/step - loss: 0.0086 - accuracy: 0.9975 - val_loss: 0.4444 - val_accuracy: 0.9955
# Epoch 38/40
# 62/62 [==============================] - 17s 273ms/step - loss: 0.0135 - accuracy: 0.9960 - val_loss: 0.3724 - val_accuracy: 0.9955
# Epoch 39/40
# 62/62 [==============================] - 17s 275ms/step - loss: 0.0096 - accuracy: 0.9985 - val_loss: 0.3239 - val_accuracy: 0.9955
# Epoch 40/40
# 62/62 [==============================] - 17s 272ms/step - loss: 0.0087 - accuracy: 0.9975 - val_loss: 0.3704 - val_accuracy: 0.9955

# %%
model.evaluate(test)
# Out:
# 9/9 [==============================] - 7s 120ms/step - loss: 0.0015 - accuracy: 1.0000
# [0.0015220270724967122, 1.0]

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

# %%
plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(range(EPOCHS), acc, label='Training Accuracy')
plt.plot(range(EPOCHS), val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(range(EPOCHS), loss, label='Training Loss')
plt.plot(range(EPOCHS), val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %%
def predict(model, img):
    img_array = tf.keras.preprocessing.image.img_to_array(images[i].numpy())
    img_array = tf.expand_dims(img_array, 0)

    predictions = model.predict(img_array)

    predicted_class = class_names[np.argmax(predictions[0])]
    confidence = round(100 * (np.max(predictions[0])), 2)
    return predicted_class, confidence

# %%
plt.figure(figsize=(15, 15))
for images, labels in test.take(1):
    for i in range(9):
        ax = plt.subplot(3, 3, i + 1)
        plt.imshow(images[i].numpy().astype("uint8"))
        
        predicted_class, confidence = predict(model, images[i].numpy())
        actual_class = class_names[labels[i]] 
        
        plt.title(f"Actual: {actual_class},\n Predicted: {predicted_class}.\n Confidence: {confidence}%")
        
        plt.axis("off")

# %%
model_version = 1
model_name = f'pepper_bell_{model_version}'
model.save(f"../saved_models/{model_name}")
# Out:
# INFO:tensorflow:Assets written to: ../saved_models/pepper_bell_1\assets
